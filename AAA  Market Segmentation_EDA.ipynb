# %% [markdown]
# # <img src= 'http://www.bigbang-datascience.com/wp-content/uploads/2017/09/cropped-Logo-01.jpg' width=500/>

# %% [markdown]
# ## <span style="color:brown">BIG BANG DATA SCIENCE
# ## <span style="color:brown">Capstone Project

# %% [markdown]
# ## <span style="color:green">Project: AAA Market Segmentation
# #### <span style="color:green">Author: Naveed Khan (naveedk786@yahoo.com)
# ***

# %% [markdown]
# ![AAA-logo.jpg](AAA-logo.jpg)

# %% [markdown]
# <a id="project-overview"></a>
# # <span style="color:blue">Project Overview

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# 1.  Provide a market segmentation of AAA members (or member households) that allows AAA Northeast to better serve their members
# 2.  Develop a series of “look-alike” models to determine the probability of purchasing each product.  Validate your models.
# 3.  Develop models to predict the likelihood of using roadside service as well as the total cost of roadside usage.

# %% [markdown]
# <a id="I"></a>
#
# ## <span style="color:blue"> Part 1.  Reading Data & Exploratory Data Analysis (EDA)

# %% [markdown]
# **Importing necessary Libraries**

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', 70)
import seaborn as sns
sns.set()  #  Will import Seaborn functionalities
# we don't like warnings
# you can comment the following 2 lines if you'd like to
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Reading csv Data**

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
aaa = pd.read_csv('member_sample.csv')

# %%
aaa = aaa.drop('Unnamed: 0', axis = 1)

# %%
aaa.head(2)
# Out:
#    Individual Key  Household Key Member Flag          City State - Grouped  \
# 0  10000003.0      10462590.0     Y           NEW HAVEN     CT
# 1  52211550.0      4500791.0      Y           WEST WARWICK  RI
#
#      ZIP5        ZIP9 FSV CMSI Flag FSV Credit Card Flag  \
# 0  6511.0  65111349.0  N             N
# 1  2893.0  28933850.0  N             Y
#
#   FSV Deposit Program Flag FSV Home Equity Flag FSV ID Theft Flag  \
# 0  N                        N                    N
# 1  N                        N                    N
#
#   FSV Mortgage Flag INS Client Flag TRV Globalware Flag Number of Children  \
# 0  N                 N               N                   NaN
# 1  N                 N               N                   One Child
#
#   Responded to Catalog                         Race  Length Of Residence  \
# 0  NaN                  NaN                         NaN
# 1  NaN                  Caucasion / White - English  15.0
#
#   Mail Responder  Home Owner     Income        Date Of Birth Children  \
# 0  NaN            NaN         NaN        NaN                  NaN
# 1  Yes            Home Owner  30-39,999  1922-02-05 00:00:00  Yes
#
#       Education                             Dwelling Type Credit Ranges  \
# 0  NaN           Small or large multi-family w/apt number  NaN
# 1  Some College  Small or large multi-family w/apt number  600-649
#
#   Language Gender Active Expiration Date  Address Change Date  \
# 0  NaN      Male   NaN                    NaN
# 1  English  NaN    2020-09-01 00:00:00    2005-01-28 12:41:09
#
#   Bad Address Flag Billing Code Description  Birth Date MMDDYYYY  \
# 0  NaN              NaN                      NaN
# 1  F                New Member               1922-02-05 00:00:00
#
#            Branch Name Cancel Date Cancel Reason County  \
# 0  NaN                  NaN         NaN           NaN
# 1  RI - WARWICK BRANCH  NaN         NaN           KENT
#
#    Do Not Direct Mail Solicit  Email Available Email Status  \
# 0 NaN                         NaN               NaN
# 1  0.0                         0.0              NaN
#
#    ERS ENT Count Year 1  ERS ENT Count Year 2  ERS ENT Count Year 3  \
# 0 NaN                   NaN                   NaN
# 1  0.0                   0.0                   2.0
#
#    ERS Member Cost Year 1  ERS Member Cost Year 2  ERS Member Cost Year 3  \
# 0 NaN                     NaN                     NaN
# 1  0.0                     0.0                     65.0
#
#   Right_Gender  Right_Individual Key        Join AAA Date  \
# 0  NaN         NaN                    NaN
# 1  NaN          52211550.0            1970-09-01 00:00:00
#
#         Join Club Date  Member Key Member Map Location  \
# 0  NaN                 NaN          NaN
# 1  1970-09-01 00:00:00  1500014.0   {41.696,-71.5308}
#
#    Member Number Associate ID Member Phone Type Member Status  \
# 0 NaN                          NaN               NaN
# 1  15300.0                     VoIP              ACTIVE
#
#    Member Tenure Years Member Type  Membership ID  Months from Join to Cancel  \
# 0 NaN                   NaN        NaN            NaN
# 1  49.0                 Primary     153.0         NaN
#
#   Opt-Out - Publication Reason Joined       Reinstate Date Renew Method  \
# 0  NaN                   NaN           NaN                  NaN
# 1  Opt-In                NaN           2019-08-23 00:00:00  AUTO RENEW
#
#       ZIP  Mosaic Household Mosaic Global Household kcl_B_IND_MosaicsGrouping  \
# 0 NaN      NaN               NaN                     NaN
# 1  2893.0  Senior Discounts  Low Income Elders       Golden Year Guardians
#
#   New Mover Flag Occupation Code Occupation Group Right_Dwelling Type  \
# 0  NaN            NaN             NaN              NaN
# 1  N              NaN             NaN              NaN
#
#   Move Distance Occupant Type Breakdown Map Location Breakdown City  \
# 0  NaN           NaN           NaN                    NaN
# 1  NaN           NaN           {41,-71}               West Warwick
#
#   Breakdown State  Basic Cost  Calculated Tow Miles Call Canceled Call Killed  \
# 0  NaN            NaN         NaN                    NaN           NaN
# 1  RI              32.5        0.8                   N             N
#
#   Call Status Recv Date Cash Call Clearing Code Last Description  \
# 0  NaN                   NaN       NaN
# 1  2017-04-13 10:05:17   Y         CASH CALL ONLY C
#
#   Dispatch Code1 Description  Dispatch Code2Description  \
# 0  NaN                       NaN
# 1  Engine Overheat           NaN
#
#   DTL Prob1 Code Description Fleet Indicator  Is Duplicate  Is NSR  \
# 0  NaN                        NaN            NaN           NaN
# 1  Engine Overheat            N               0.0           0.0
#
#    Member Match Flag  Member Number and Associate ID Motorcycle Indicator  \
# 0 NaN                NaN                              NaN
# 1  1.0                15300.0                         N
#
#    Plus Cost Plus Indicator Description  Premier Cost Prob1 Code Description  \
# 0 NaN         NaN                       NaN            NaN
# 1  0.0        Basic Membership           0.0           Tow
#
#   Prob2 Code Description SC Call Club Code Description              SC Date  \
# 0  NaN                    NaN                           NaN
# 1  NaN                    AAA Northeast                 2017-04-13 00:00:00
#
#       Rec ID SC STS RSN Code Description SC Vehicle Manufacturer Name  \
# 0 NaN         NaN                         NaN
# 1  9707320.0  CASH CALL ONLY C            TOYOTA
#
#   SC Vehicle Model Name      SVC Facility Name   SVC Facility Type  \
# 0  NaN                   NaN                    NaN
# 1  CAMRY                 ASTRO WRECKER SERVICE  independent repair
#
#    Total Cost  Tow Destination Latitude  Tow Destination Longitude  \
# 0 NaN         NaN                       NaN
# 1  32.5        41.0                     -71.0
#
#            Tow Destination Name  Was Duplicated  Was Towed To AAR Referral
# 0  NaN                          NaN             NaN
# 1  Aar / Johnson's Auto Service  0.0             1.0

# %%
aaa.shape
# Out:
# (21344, 112)

# %%
# aaa.info()

# %%
#aaa.describe()

# %% [markdown]
# **Normalizing column names**

# %%
# Stripping out spaces from ends of names, and replacing internal spaces with "_"
print("\nStripping spaces from ends of column names; replacing internal spaces with '_'\n")

aaa.columns = [col.strip().replace(' ', '_').lower() for col in aaa.columns]
aaa.columns = [col.strip().replace('-', '_').lower() for col in aaa.columns]

# Print edited column names
print("\nNew Column Names:\n", aaa.columns)
# Out:
# Stripping spaces from ends of column names; replacing internal spaces with '_'
#
#
# New Column Names:
#  Index(['individual_key', 'household_key', 'member_flag', 'city',
#        'state___grouped', 'zip5', 'zip9', 'fsv_cmsi_flag',
#        'fsv_credit_card_flag', 'fsv_deposit_program_flag',
#        ...
#        'sc_vehicle_manufacturer_name', 'sc_vehicle_model_name',
#        'svc_facility_name', 'svc_facility_type', 'total_cost',
#        'tow_destination_latitude', 'tow_destination_longitude',
#        'tow_destination_name', 'was_duplicated', 'was_towed_to_aar_referral'],
#       dtype='object', length=112)

# %%
# aaa['individual_key'].value_counts()

# %%
# group by the 'label' and show descriptive stats
#aaa.groupby('individual_key').agg(['count', 'mean','std','min','max','median']).T.head()

# %% [markdown]
# **Dropping unimportant features: duplicate IDs, personal info, etc.**

# %%
aaa = aaa.drop(columns=['individual_key', 'right_individual_key','member_number_associate_id',
                        'membership_id','join_club_date'])

# %%
aaa = aaa.drop(columns=['city', 'state___grouped', 'zip5','zip9','county','branch_name'])

# %%
aaa = aaa.drop(columns=['race', 'gender', 'right_gender','language','education','email_available','email_status',
                        'member_phone_type','date_of_birth'])

# %%
aaa = aaa.drop(columns=['address_change_date', 'bad_address_flag', 'billing_code_description','cancel_date',
                        'cancel_reason','join_aaa_date','months_from_join_to_cancel',
                       'reason_joined','reinstate_date','renew_method','member_match_flag'])

# %%
aaa = aaa.drop(columns=['breakdown_map_location', 'breakdown_city', 'breakdown_state','call_canceled',
                        'call_killed','call_status_recv_date','cash_call','clearing_code_last_description',
                       'dispatch_code1_description','dispatch_code2description','dtl_prob1_code_description',
                       'is_duplicate','is_nsr','prob2_code_description','sc_sts_rsn_code_description',
                        'sc_vehicle_manufacturer_name','sc_vehicle_model_name','svc_facility_name',
                       'svc_facility_type','tow_destination_name','was_duplicated','was_towed_to_aar_referral'])

# %%
# Removing features with >95% missing values
aaa = aaa.drop(columns=['responded_to_catalog','right_dwelling_type','move_distance','occupant_type'])

# %% [markdown]
# **Moving 'member_key' as the first column**

# %%
first_col = aaa.pop('member_key')
aaa.insert(0, 'member_key',first_col)

# %%
aaa.head(2)
# Out:
#    member_key  household_key member_flag fsv_cmsi_flag fsv_credit_card_flag  \
# 0 NaN          10462590.0     Y           N             N
# 1  1500014.0   4500791.0      Y           N             Y
#
#   fsv_deposit_program_flag fsv_home_equity_flag fsv_id_theft_flag  \
# 0  N                        N                    N
# 1  N                        N                    N
#
#   fsv_mortgage_flag ins_client_flag trv_globalware_flag number_of_children  \
# 0  N                 N               N                   NaN
# 1  N                 N               N                   One Child
#
#    length_of_residence mail_responder  home_owner     income children  \
# 0 NaN                   NaN            NaN         NaN        NaN
# 1  15.0                 Yes            Home Owner  30-39,999  Yes
#
#                               dwelling_type credit_ranges  \
# 0  Small or large multi-family w/apt number  NaN
# 1  Small or large multi-family w/apt number  600-649
#
#   active_expiration_date  birth_date_mmddyyyy  do_not_direct_mail_solicit  \
# 0  NaN                    NaN                 NaN
# 1  2020-09-01 00:00:00    1922-02-05 00:00:00  0.0
#
#    ers_ent_count_year_1  ers_ent_count_year_2  ers_ent_count_year_3  \
# 0 NaN                   NaN                   NaN
# 1  0.0                   0.0                   2.0
#
#    ers_member_cost_year_1  ers_member_cost_year_2  ers_member_cost_year_3  \
# 0 NaN                     NaN                     NaN
# 1  0.0                     0.0                     65.0
#
#   member_map_location member_status  member_tenure_years member_type  \
# 0  NaN                 NaN          NaN                   NaN
# 1  {41.696,-71.5308}   ACTIVE        49.0                 Primary
#
#   opt_out___publication     zip  mosaic_household mosaic_global_household  \
# 0  NaN                  NaN      NaN               NaN
# 1  Opt-In                2893.0  Senior Discounts  Low Income Elders
#
#   kcl_b_ind_mosaicsgrouping new_mover_flag occupation_code occupation_group  \
# 0  NaN                       NaN            NaN             NaN
# 1  Golden Year Guardians     N              NaN             NaN
#
#    basic_cost  calculated_tow_miles fleet_indicator  \
# 0 NaN         NaN                    NaN
# 1  32.5        0.8                   N
#
#    member_number_and_associate_id motorcycle_indicator  plus_cost  \
# 0 NaN                              NaN                 NaN
# 1  15300.0                         N                    0.0
#
#   plus_indicator_description  premier_cost prob1_code_description  \
# 0  NaN                       NaN            NaN
# 1  Basic Membership           0.0           Tow
#
#   sc_call_club_code_description              sc_date     rec_id  total_cost  \
# 0  NaN                           NaN                 NaN        NaN
# 1  AAA Northeast                 2017-04-13 00:00:00  9707320.0  32.5
#
#    tow_destination_latitude  tow_destination_longitude
# 0 NaN                       NaN
# 1  41.0                     -71.0

# %%
print("Reduced dataframe size after features removal: ",aaa.shape )
# Out:
# Reduced dataframe size after features removal:  (21344, 55)

# %% [markdown]
# **Remove inactive Members**

# %%
aaa['member_status'].fillna('UNKNOWN', inplace = True)

# %%
aaa['member_status'].value_counts()
# Out:
# ACTIVE       11808
# CANCELLED    8177
# PENDING      1358
# UNKNOWN      1
# Name: member_status, dtype: int64

# %%
aaa = aaa.loc[(aaa['member_status']!='CANCELLED') & (aaa['member_status']!='UNKNOWN')]

# %%
aaa['member_status'].hist()
# Out:
# <AxesSubplot:>

# %%
print("Reduced Memebers size after removal of cancelled members: ")
aaa['member_status'].value_counts()
# Out:
# Reduced Memebers size after removal of cancelled members:
# ACTIVE     11808
# PENDING    1358
# Name: member_status, dtype: int64

# %%
print("Reduced dataframe size after Cancelled Members removed: ",aaa.shape)
# Out:
# Reduced dataframe size after Cancelled Members removed:  (13166, 55)

# %%
#aaa.groupby('household_key').agg(['count', 'mean','std','min','max','median']).T.head(20)

# %%
aaa.describe(include=['object', 'bool'])
# Out:
#        member_flag fsv_cmsi_flag fsv_credit_card_flag  \
# count   13166       13166         13166
# unique  1           2             2
# top     Y           N             N
# freq    13166       12368         12098
#
#        fsv_deposit_program_flag fsv_home_equity_flag fsv_id_theft_flag  \
# count   13166                    13166                13166
# unique  2                        2                    2
# top     N                        N                    N
# freq    13125                    13161                12726
#
#        fsv_mortgage_flag ins_client_flag trv_globalware_flag  \
# count   13166             13166           13166
# unique  2                 2               2
# top     N                 N               N
# freq    13140             10402           11511
#
#        number_of_children mail_responder  home_owner       income children  \
# count   9611               9611           9380        9569         9611
# unique  7                  2              4           15           2
# top     No children        Yes            Home Owner  100-149,999  Yes
# freq    4336               9227           9051        2129         5334
#
#        dwelling_type credit_ranges active_expiration_date  \
# count   10173         9611          13166
# unique  4             9             25
# top     SFDU          750-799       2020-01-01 00:00:00
# freq    8661          3260          1453
#
#         birth_date_mmddyyyy member_map_location member_status member_type  \
# count   12816                13153               13166         13166
# unique  4864                 3193                2             2
# top     1984-10-22 00:00:00  {41.818,-71.4475}   ACTIVE        Primary
# freq    21                   35                  11808         8011
#
#        opt_out___publication mosaic_household mosaic_global_household  \
# count   13166                 10163            10163
# unique  2                     62               10
# top     Opt-In                Aging in Place   Comfortable Retirement
# freq    13075                 2084             3263
#
#        kcl_b_ind_mosaicsgrouping new_mover_flag occupation_code  \
# count   10163                     13166          7291
# unique  19                        2              38
# top     Autumn Years              N              Unknown
# freq    2181                      12639          4217
#
#           occupation_group fleet_indicator motorcycle_indicator  \
# count   7291                11067           10564
# unique  17                  2               2
# top     Retired - Inferred  Y               N
# freq    2090                6918            7309
#
#        plus_indicator_description prob1_code_description  \
# count   11178                      11178
# unique  4                          15
# top     Basic Membership           Tow
# freq    5887                       3627
#
#        sc_call_club_code_description              sc_date
# count   11178                         11178
# unique  17                            1481
# top     AAA Northeast                 2019-01-22 00:00:00
# freq    11055                         30

# %% [markdown]
# ### Data Visualization

# %%
corr_matrix = aaa.corr()  # corr(autinsurance)
corr_matrix
# Out:
#                                 member_key  household_key  \
# member_key                      1.000000   -0.012206
# household_key                  -0.012206    1.000000
# length_of_residence            -0.058156   -0.031348
# do_not_direct_mail_solicit     -0.004686    0.000268
# ers_ent_count_year_1            0.043138   -0.031225
# ers_ent_count_year_2            0.048504   -0.012097
# ers_ent_count_year_3            0.063688    0.011300
# ers_member_cost_year_1          0.056607   -0.034231
# ers_member_cost_year_2          0.062404   -0.015534
# ers_member_cost_year_3          0.054179    0.021126
# member_tenure_years            -0.461549   -0.007779
# zip                             0.015705   -0.007817
# basic_cost                     -0.024498   -0.002107
# calculated_tow_miles            0.040136    0.006679
# member_number_and_associate_id -0.034136   -0.031619
# plus_cost                       0.025933   -0.004485
# premier_cost                    0.001542   -0.006080
# rec_id                         -0.004280   -0.009942
# total_cost                      0.004210   -0.007960
# tow_destination_latitude        0.033902    0.008699
# tow_destination_longitude      -0.033994   -0.009054
#
#                                 length_of_residence  \
# member_key                     -0.058156
# household_key                  -0.031348
# length_of_residence             1.000000
# do_not_direct_mail_solicit     -0.033667
# ers_ent_count_year_1            0.039345
# ers_ent_count_year_2            0.021087
# ers_ent_count_year_3           -0.008625
# ers_member_cost_year_1          0.028364
# ers_member_cost_year_2          0.033847
# ers_member_cost_year_3         -0.004710
# member_tenure_years             0.103971
# zip                            -0.043177
# basic_cost                     -0.005129
# calculated_tow_miles           -0.019740
# member_number_and_associate_id -0.041474
# plus_cost                      -0.027658
# premier_cost                   -0.017886
# rec_id                          0.018801
# total_cost                     -0.029500
# tow_destination_latitude       -0.005800
# tow_destination_longitude       0.006030
#
#                                 do_not_direct_mail_solicit  \
# member_key                     -0.004686
# household_key                   0.000268
# length_of_residence            -0.033667
# do_not_direct_mail_solicit      1.000000
# ers_ent_count_year_1           -0.001251
# ers_ent_count_year_2            0.019326
# ers_ent_count_year_3            0.012455
# ers_member_cost_year_1         -0.000915
# ers_member_cost_year_2          0.029439
# ers_member_cost_year_3          0.011067
# member_tenure_years            -0.024687
# zip                             0.041015
# basic_cost                     -0.010714
# calculated_tow_miles           -0.005307
# member_number_and_associate_id  0.012445
# plus_cost                       0.002045
# premier_cost                   -0.001985
# rec_id                          0.008910
# total_cost                     -0.008451
# tow_destination_latitude       -0.009015
# tow_destination_longitude       0.008944
#
#                                 ers_ent_count_year_1  ers_ent_count_year_2  \
# member_key                      0.043138              0.048504
# household_key                  -0.031225             -0.012097
# length_of_residence             0.039345              0.021087
# do_not_direct_mail_solicit     -0.001251              0.019326
# ers_ent_count_year_1            1.000000              0.260569
# ers_ent_count_year_2            0.260569              1.000000
# ers_ent_count_year_3            0.287053              0.340213
# ers_member_cost_year_1          0.941087              0.251091
# ers_member_cost_year_2          0.236600              0.908167
# ers_member_cost_year_3          0.281090              0.325094
# member_tenure_years            -0.086768             -0.060711
# zip                            -0.012903              0.005382
# basic_cost                      0.035648              0.046505
# calculated_tow_miles            0.018691              0.019609
# member_number_and_associate_id  0.006566              0.042640
# plus_cost                       0.018131              0.019382
# premier_cost                   -0.003985             -0.009282
# rec_id                          0.231218              0.218890
# total_cost                      0.033676              0.044069
# tow_destination_latitude        0.090857              0.107410
# tow_destination_longitude      -0.089686             -0.106227
#
#                                 ers_ent_count_year_3  ers_member_cost_year_1  \
# member_key                      0.063688              0.056607
# household_key                   0.011300             -0.034231
# length_of_residence            -0.008625              0.028364
# do_not_direct_mail_solicit      0.012455             -0.000915
# ers_ent_count_year_1            0.287053              0.941087
# ers_ent_count_year_2            0.340213              0.251091
# ers_ent_count_year_3            1.000000              0.271477
# ers_member_cost_year_1          0.271477              1.000000
# ers_member_cost_year_2          0.310244              0.257626
# ers_member_cost_year_3          0.925076              0.287965
# member_tenure_years            -0.081704             -0.089345
# zip                            -0.016790             -0.007926
# basic_cost                      0.010670              0.074543
# calculated_tow_miles            0.018814              0.063525
# member_number_and_associate_id  0.000045              0.020709
# plus_cost                       0.012883              0.064487
# premier_cost                   -0.007706             -0.002708
# rec_id                          0.042503              0.213620
# total_cost                      0.017346              0.091389
# tow_destination_latitude        0.025860              0.107134
# tow_destination_longitude      -0.025691             -0.105959
#
#                                 ers_member_cost_year_2  \
# member_key                      0.062404
# household_key                  -0.015534
# length_of_residence             0.033847
# do_not_direct_mail_solicit      0.029439
# ers_ent_count_year_1            0.236600
# ers_ent_count_year_2            0.908167
# ers_ent_count_year_3            0.310244
# ers_member_cost_year_1          0.257626
# ers_member_cost_year_2          1.000000
# ers_member_cost_year_3          0.321876
# member_tenure_years            -0.053529
# zip                             0.006104
# basic_cost                      0.091778
# calculated_tow_miles            0.073947
# member_number_and_associate_id  0.037138
# plus_cost                       0.081953
# premier_cost                   -0.008089
# rec_id                          0.179718
# total_cost                      0.120296
# tow_destination_latitude        0.118532
# tow_destination_longitude      -0.117604
#
#                                 ers_member_cost_year_3  member_tenure_years  \
# member_key                      0.054179               -0.461549
# household_key                   0.021126               -0.007779
# length_of_residence            -0.004710                0.103971
# do_not_direct_mail_solicit      0.011067               -0.024687
# ers_ent_count_year_1            0.281090               -0.086768
# ers_ent_count_year_2            0.325094               -0.060711
# ers_ent_count_year_3            0.925076               -0.081704
# ers_member_cost_year_1          0.287965               -0.089345
# ers_member_cost_year_2          0.321876               -0.053529
# ers_member_cost_year_3          1.000000               -0.078027
# member_tenure_years            -0.078027                1.000000
# zip                            -0.016844               -0.013138
# basic_cost                      0.042081                0.034757
# calculated_tow_miles            0.057266               -0.043104
# member_number_and_associate_id  0.009540                0.024531
# plus_cost                       0.052800               -0.022297
# premier_cost                   -0.007090               -0.006860
# rec_id                          0.036067                0.008791
# total_cost                      0.066317                0.006818
# tow_destination_latitude        0.041168               -0.061782
# tow_destination_longitude      -0.040942                0.061372
#
#                                      zip  basic_cost  calculated_tow_miles  \
# member_key                      0.015705 -0.024498    0.040136
# household_key                  -0.007817 -0.002107    0.006679
# length_of_residence            -0.043177 -0.005129   -0.019740
# do_not_direct_mail_solicit      0.041015 -0.010714   -0.005307
# ers_ent_count_year_1           -0.012903  0.035648    0.018691
# ers_ent_count_year_2            0.005382  0.046505    0.019609
# ers_ent_count_year_3           -0.016790  0.010670    0.018814
# ers_member_cost_year_1         -0.007926  0.074543    0.063525
# ers_member_cost_year_2          0.006104  0.091778    0.073947
# ers_member_cost_year_3         -0.016844  0.042081    0.057266
# member_tenure_years            -0.013138  0.034757   -0.043104
# zip                             1.000000  0.018418    0.010969
# basic_cost                      0.018418  1.000000   -0.041945
# calculated_tow_miles            0.010969 -0.041945    1.000000
# member_number_and_associate_id  0.082839 -0.020797    0.034312
# plus_cost                       0.023550 -0.055438    0.770436
# premier_cost                   -0.001288 -0.001350    0.153025
# rec_id                         -0.000582  0.077647    0.003854
# total_cost                      0.029770  0.579175    0.556211
# tow_destination_latitude       -0.005951 -0.060504    0.491185
# tow_destination_longitude       0.005598  0.060596   -0.492272
#
#                                 member_number_and_associate_id  plus_cost  \
# member_key                     -0.034136                        0.025933
# household_key                  -0.031619                       -0.004485
# length_of_residence            -0.041474                       -0.027658
# do_not_direct_mail_solicit      0.012445                        0.002045
# ers_ent_count_year_1            0.006566                        0.018131
# ers_ent_count_year_2            0.042640                        0.019382
# ers_ent_count_year_3            0.000045                        0.012883
# ers_member_cost_year_1          0.020709                        0.064487
# ers_member_cost_year_2          0.037138                        0.081953
# ers_member_cost_year_3          0.009540                        0.052800
# member_tenure_years             0.024531                       -0.022297
# zip                             0.082839                        0.023550
# basic_cost                     -0.020797                       -0.055438
# calculated_tow_miles            0.034312                        0.770436
# member_number_and_associate_id  1.000000                        0.057680
# plus_cost                       0.057680                        1.000000
# premier_cost                    0.007157                        0.236426
# rec_id                          0.033349                        0.011815
# total_cost                      0.031354                        0.719864
# tow_destination_latitude        0.014984                        0.259989
# tow_destination_longitude      -0.014669                       -0.261415
#
#                                 premier_cost    rec_id  total_cost  \
# member_key                      0.001542     -0.004280  0.004210
# household_key                  -0.006080     -0.009942 -0.007960
# length_of_residence            -0.017886      0.018801 -0.029500
# do_not_direct_mail_solicit     -0.001985      0.008910 -0.008451
# ers_ent_count_year_1           -0.003985      0.231218  0.033676
# ers_ent_count_year_2           -0.009282      0.218890  0.044069
# ers_ent_count_year_3           -0.007706      0.042503  0.017346
# ers_member_cost_year_1         -0.002708      0.213620  0.091389
# ers_member_cost_year_2         -0.008089      0.179718  0.120296
# ers_member_cost_year_3         -0.007090      0.036067  0.066317
# member_tenure_years            -0.006860      0.008791  0.006818
# zip                            -0.001288     -0.000582  0.029770
# basic_cost                     -0.001350      0.077647  0.579175
# calculated_tow_miles            0.153025      0.003854  0.556211
# member_number_and_associate_id  0.007157      0.033349  0.031354
# plus_cost                       0.236426      0.011815  0.719864
# premier_cost                    1.000000     -0.000224  0.221972
# rec_id                         -0.000224      1.000000  0.047958
# total_cost                      0.221972      0.047958  1.000000
# tow_destination_latitude        0.015406      0.350305  0.153709
# tow_destination_longitude      -0.016651     -0.346222 -0.154901
#
#                                 tow_destination_latitude  \
# member_key                      0.033902
# household_key                   0.008699
# length_of_residence            -0.005800
# do_not_direct_mail_solicit     -0.009015
# ers_ent_count_year_1            0.090857
# ers_ent_count_year_2            0.107410
# ers_ent_count_year_3            0.025860
# ers_member_cost_year_1          0.107134
# ers_member_cost_year_2          0.118532
# ers_member_cost_year_3          0.041168
# member_tenure_years            -0.061782
# zip                            -0.005951
# basic_cost                     -0.060504
# calculated_tow_miles            0.491185
# member_number_and_associate_id  0.014984
# plus_cost                       0.259989
# premier_cost                    0.015406
# rec_id                          0.350305
# total_cost                      0.153709
# tow_destination_latitude        1.000000
# tow_destination_longitude      -0.999928
#
#                                 tow_destination_longitude
# member_key                     -0.033994
# household_key                  -0.009054
# length_of_residence             0.006030
# do_not_direct_mail_solicit      0.008944
# ers_ent_count_year_1           -0.089686
# ers_ent_count_year_2           -0.106227
# ers_ent_count_year_3           -0.025691
# ers_member_cost_year_1         -0.105959
# ers_member_cost_year_2         -0.117604
# ers_member_cost_year_3         -0.040942
# member_tenure_years             0.061372
# zip                             0.005598
# basic_cost                      0.060596
# calculated_tow_miles           -0.492272
# member_number_and_associate_id -0.014669
# plus_cost                      -0.261415
# premier_cost                   -0.016651
# rec_id                         -0.346222
# total_cost                     -0.154901
# tow_destination_latitude       -0.999928
# tow_destination_longitude       1.000000

# %%
#### Correlation heatmap of the numberic variables
plt.rcParams['figure.figsize'] = 20,10  # control plot sizeimport seaborn as sns
sns.heatmap(aaa.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id="IV"></a>
# ### Visual Data Analysis in with SweetViz

# %%
# Import Libraries
print('Importing Libraries ... ',end='')
import sweetviz as sv
import pandas as pd
print('Done')
# Out:
# Importing Libraries ... Done

# %%
# Analyzing data
report=sv.analyze(aaa)

# Generating report
report.show_html('eda_report.html')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, layout=Layout(flex='2'), max=56.0), HTML(value='')), l…
# Report eda_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# **Save the Clean Data File - Version2**

# %%
aaa.to_csv('aaa_data_Version2.csv')
